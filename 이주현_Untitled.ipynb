# %% [markdown]
# <a href="https://colab.research.google.com/github/Muldark/2026-programming/blob/main/%EC%9D%B4%EC%A3%BC%ED%98%84_Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1print("hell")
# Out:
#   File "/tmp/ipykernel_255/1811989364.py", line 1
#     1print("hell")
#     ^
# SyntaxError: invalid decimal literal
